# %%
import pandas as pd 

data = pd.read_csv("C:/data science/UPI Transaction/UPI Transactions 23 24.csv")
data.head()
# Out:
#    Customer ID         Transaction ID  Transaction Amount  \
# 0  77243371982  903126106589788681456            14993.73
# 1  23355397215  802025143491598348865             2534.80
# 2  10153181199  461983386094521109412            10478.46
# 3  18868368192  910240804704991412414              471.46
# 4  58296809443  366853468515876436170            63391.63
#
#   Amount Sent DateTime Amount Received DateTime  Recipient ID  \
# 0  2023-10-06 02:55:42      2023-10-06 02:56:26    3697158788
# 1  2023-12-07 22:18:56      2023-12-07 22:19:37   72886924680
# 2  2023-08-25 06:13:42      2023-08-25 06:14:26   55813045668
# 3  2023-12-09 18:46:38      2023-12-09 18:47:22   46862003071
# 4  2023-12-26 17:22:51      2023-12-26 17:23:32    3966148803
#
#   Transaction Category Payment Method Transaction Status  Customer Age  \
# 0               Travel            UPI            Success            22
# 1               Travel            UPI            Success            25
# ...

# %%
data.tail()
# Out:
#        Customer ID         Transaction ID  Transaction Amount  \
# 49995  24746532553  699094054108977799256             3231.28
# 49996  57775263059  564916336922738227856              681.59
# 49997  59736372767  723220415466185635628             1316.51
# 49998  62183867285  763599955223601516518              970.72
# 49999   9916091857  491887687369662320583              235.01
#
#       Amount Sent DateTime Amount Received DateTime  Recipient ID  \
# 49995  2024-04-20 16:26:29      2024-04-20 16:27:12   64876985810
# 49996  2023-12-09 18:54:17      2023-12-09 18:55:00   76895922356
# 49997  2023-11-11 04:52:28      2023-11-11 04:53:10   99520678569
# 49998  2023-07-08 09:13:16      2023-07-08 09:13:59   65243376681
# 49999  2023-09-04 11:02:20      2023-09-04 11:03:05   24503703883
#
#       Transaction Category Payment Method Transaction Status  Customer Age  \
# 49995             Shopping            UPI            Success            31
# ...

# %%
data.shape
# Out:
# (50000, 16)

# %%
data.columns
# Out:
# Index(['Customer ID', 'Transaction ID', 'Transaction Amount',
#        'Amount Sent DateTime', 'Amount Received DateTime', 'Recipient ID',
#        'Transaction Category', 'Payment Method', 'Transaction Status',
#        'Customer Age', 'Sender Bank', 'Receiver Bank', 'From State',
#        'To State', 'UPI App', 'Transaction Device'],
#       dtype='object')

# %%
data[['Customer ID', 'Customer Age']]
# Out:
#        Customer ID  Customer Age
# 0      77243371982            22
# 1      23355397215            25
# 2      10153181199            64
# 3      18868368192            29
# 4      58296809443            44
# ...            ...           ...
# 49995  24746532553            31
# 49996  57775263059            21
# 49997  59736372767            25
# 49998  62183867285            25
# 49999   9916091857            40
#
# [50000 rows x 2 columns]

# %%
data.loc[0]
data.loc[0:2, ['Customer ID', 'Customer Age']]
# Out:
#    Customer ID  Customer Age
# 0  77243371982            22
# 1  23355397215            25
# 2  10153181199            64

# %%
data.iloc[0:2]
data.iloc[0:2, 0:3]
# Out:
#    Customer ID         Transaction ID  Transaction Amount
# 0  77243371982  903126106589788681456            14993.73
# 1  23355397215  802025143491598348865             2534.80

# %%
data.rank()
data.sort_index()
data.sort_values(by='Customer Age')
# Out:
#        Customer ID         Transaction ID  Transaction Amount  \
# 17332   4163420189  607278387995071319991              477.88
# 27177  91652108837  611297577224021024854            80975.33
# 22964   9177753844  920682270505799785685            13078.00
# 1954    5279683962  201141100957948401696             9086.84
# 31530  84253070490  257450030311365948114             2036.42
# ...            ...                    ...                 ...
# 14636  42711969531  592509699284907090093             9470.56
# 6052   26529906602  787356748139138500560            14060.46
# 14546  23700872661  447206651527755521281              985.78
# 4924   21452102923  846038224827694060071              241.92
# 7968   15836348189  224644570737016338268              606.77
#
#       Amount Sent DateTime Amount Received DateTime  Recipient ID  \
# 17332  2023-11-22 04:59:47      2023-11-22 05:00:32   97597280329
# 27177  2024-02-19 07:38:10      2024-02-19 07:38:52   95975410954
# ...

# %%
data.groupby('Customer Age').sum()
data.agg({'Transaction Amount': 'mean', 'Customer Age': 'sum'})
# Out:
# Transaction Amount    9.897481e+03
# Customer Age          1.641009e+06
# dtype: float64

# %%
data['Customer Age'].apply(lambda x: x + 2)
# Out:
# 0        24
# 1        27
# 2        66
# 3        31
# 4        46
#          ..
# 49995    33
# 49996    23
# 49997    27
# 49998    27
# 49999    42
# Name: Customer Age, Length: 50000, dtype: int64

# %%
data['Transaction Category'].map(str.upper)
# Out:
# 0                TRAVEL
# 1                TRAVEL
# 2                TRAVEL
# 3              SHOPPING
# 4            MOVIE BILL
#               ...
# 49995          SHOPPING
# 49996    LOAN REPAYMENT
# 49997        WATER BILL
# 49998           GROCERY
# 49999              RENT
# Name: Transaction Category, Length: 50000, dtype: object

# %%
data[data['Customer Age'] < 25]
data[(data['Customer Age'] < 25) & (data['From State'] == 'Goa')]
# Out:
#        Customer ID         Transaction ID  Transaction Amount  \
# 5      24575631791  150109138848581786598              814.38
# 47     57178099383  306893032196851259574              245.91
# 316    93720012545  190883953169183119430             2585.85
# 343    32774466041  669877711279384081198              573.35
# 423    82464613680  420851745454339622409              620.95
# ...            ...                    ...                 ...
# 49499  10296863518  899940089564635867623             5390.69
# 49526  88222963953   44390470802269536370              316.65
# 49578  68859706873   66203344059546070697              924.85
# 49617  28312646582  390659032352924037718            42708.80
# 49980  32289854527  303814622915506267049              312.12
#
#       Amount Sent DateTime Amount Received DateTime  Recipient ID  \
# 5      2023-08-31 12:59:02      2023-08-31 12:59:46   92540416376
# 47     2023-07-26 16:21:15      2023-07-26 16:21:57   45162741520
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               50000 non-null  int64
#  1   Transaction ID            50000 non-null  object
#  2   Transaction Amount        50000 non-null  float64
#  3   Amount Sent DateTime      50000 non-null  object
#  4   Amount Received DateTime  50000 non-null  object
#  5   Recipient ID              50000 non-null  int64
#  6   Transaction Category      50000 non-null  object
#  7   Payment Method            50000 non-null  object
#  8   Transaction Status        50000 non-null  object
#  9   Customer Age              50000 non-null  int64
#  10  Sender Bank               50000 non-null  object
#  11  Receiver Bank             50000 non-null  object
#  12  From State                50000 non-null  object
# ...

# %%
data.describe()
# Out:
#         Customer ID  Transaction Amount  Recipient ID  Customer Age
# count  5.000000e+04        50000.000000  5.000000e+04  50000.000000
# mean   4.981148e+10         9897.481284  5.009342e+10     32.820180
# std    2.894179e+10        18096.930989  2.889500e+10     12.148447
# min    5.247430e+05           10.020000  8.153150e+05     18.000000
# 25%    2.472180e+10          504.465000  2.509678e+10     24.000000
# 50%    4.964145e+10          992.910000  5.015163e+10     31.000000
# 75%    7.486500e+10        10801.437500  7.512568e+10     38.000000
# max    9.999753e+10        99995.240000  9.999832e+10     75.000000

# %%
data.set_index('Customer Age')
data.reset_index(drop=True)
# Out:
#        Customer ID         Transaction ID  Transaction Amount  \
# 0      77243371982  903126106589788681456            14993.73
# 1      23355397215  802025143491598348865             2534.80
# 2      10153181199  461983386094521109412            10478.46
# 3      18868368192  910240804704991412414              471.46
# 4      58296809443  366853468515876436170            63391.63
# ...            ...                    ...                 ...
# 49995  24746532553  699094054108977799256             3231.28
# 49996  57775263059  564916336922738227856              681.59
# 49997  59736372767  723220415466185635628             1316.51
# 49998  62183867285  763599955223601516518              970.72
# 49999   9916091857  491887687369662320583              235.01
#
#       Amount Sent DateTime Amount Received DateTime  Recipient ID  \
# 0      2023-10-06 02:55:42      2023-10-06 02:56:26    3697158788
# 1      2023-12-07 22:18:56      2023-12-07 22:19:37   72886924680
# ...

# %%
data.pivot_table(index='Customer ID', values='Customer Age', aggfunc='sum')
# Out:
#              Customer Age
# Customer ID
# 524743                 35
# 1225970                34
# 2711784                37
# 2756743                42
# 3424898                37
# ...                   ...
# 99994019905            23
# 99995710755            37
# 99995778230            27
# 99997121010            26
# 99997525801            26
#
# [50000 rows x 1 columns]

# %%
year = data['Amount Sent DateTime'].dt.year
year
# Out:
# 0        2023
# 1        2023
# 2        2023
# 3        2023
# 4        2023
#          ...
# 49995    2024
# 49996    2023
# 49997    2023
# 49998    2023
# 49999    2023
# Name: Amount Sent DateTime, Length: 50000, dtype: int32

# %%
day = data['Amount Sent DateTime'].dt.day_name()
day
# Out:
# 0          Friday
# 1        Thursday
# 2          Friday
# 3        Saturday
# 4         Tuesday
#            ...
# 49995    Saturday
# 49996    Saturday
# 49997    Saturday
# 49998    Saturday
# 49999      Monday
# Name: Amount Sent DateTime, Length: 50000, dtype: object

# %%
data.duplicated(subset=['Customer ID', 'Customer Age'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Length: 50000, dtype: bool

# %%
df = data['Transaction Category'].str.contains('Bill')
df
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 49995    False
# 49996    False
# 49997     True
# 49998    False
# 49999    False
# Name: Transaction Category, Length: 50000, dtype: bool

# %%
df = data['Transaction Category'].astype('category')
df
# Out:
# 0                Travel
# 1                Travel
# 2                Travel
# 3              Shopping
# 4            Movie Bill
#               ...
# 49995          Shopping
# 49996    Loan Repayment
# 49997        Water Bill
# 49998           Grocery
# 49999              Rent
# Name: Transaction Category, Length: 50000, dtype: category
# Categories (10, object): ['Dining', 'Electricity Bill', 'Grocery', 'Insurance', ..., 'Rent', 'Shopping', 'Travel', 'Water Bill']
